# %% [markdown]
# **Observations Based on the Data**
#
# Capomulin and Ramicane have a relatively small mean final volume tumor size per mouse, as well as a relatively small interquartile range compared with Ceftamin and Infubinol. This could suggest Capomulin and Ramicane are more effect of a treatment than their counter parts. More analysis would need to be done to verify.
# Mouse b128 showed a consist (although not perfect) decline in tumor volume over time on the Capomulin drug regimen
# Mouse weight and average tumor volume is highly correlated with a correlation coefficient of 0.8419363424694717

# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
#Reading in both data sets
data1_path = 'Resources/mouse_metadata.csv'
data2_path = 'Resources/study_results.csv'

data1 = pd.read_csv(data1_path)
data2 = pd.read_csv(data2_path)

# %%
#merging the data sets
df = pd.merge(data1,data2, on='Mouse ID')
df.count()
# Out:
# Mouse ID              1893
# Drug Regimen          1893
# Sex                   1893
# Age_months            1893
# Weight (g)            1893
# Timepoint             1893
# Tumor Volume (mm3)    1893
# Metastatic Sites      1893
# dtype: int64

# %%
print(len(pd.unique(df['Mouse ID'])))
# Out:
# 249

# %%
#cleaning up the duplicate time point data for each mouse
cleaned_df = df.drop_duplicates(subset=['Mouse ID','Timepoint'])
cleaned_df.count()
# Out:
# Mouse ID              1888
# Drug Regimen          1888
# Sex                   1888
# Age_months            1888
# Weight (g)            1888
# Timepoint             1888
# Tumor Volume (mm3)    1888
# Metastatic Sites      1888
# dtype: int64

# %%
#checking to make sure there are the same amount of mouse in cleaned data set
print(len(pd.unique(cleaned_df['Mouse ID'])))
# Out:
# 249

# %%
#Summary Stats of tumor volume for each drug Regimen
placeholder = cleaned_df.groupby('Drug Regimen')
a = placeholder['Tumor Volume (mm3)'].mean()
b = placeholder['Tumor Volume (mm3)'].median()
c = placeholder['Tumor Volume (mm3)'].std()
d = placeholder['Tumor Volume (mm3)'].sem()
drug_mean = a.to_frame()
drug_median = b.to_frame()
drug_std = c.to_frame()
drug_sem = d.to_frame()

Drug_Regimen_SumStats_df = pd.concat([drug_mean,drug_median,drug_std,drug_sem],axis=1)
Drug_Regimen_SumStats_df.columns = ['Mean Tumor Volume (mm3)','Median Tumor Volume (mm3)', 'Standard Deviation','Standard Error of the Mean']
Drug_Regimen_SumStats_df
# Out:
#               Mean Tumor Volume (mm3)  Median Tumor Volume (mm3)  \
# Drug Regimen
# Capomulin                   40.675741                  41.557809
# Ceftamin                    52.591172                  51.776157
# Infubinol                   52.884795                  51.820584
# Ketapril                    55.235638                  53.698743
# Naftisol                    54.331565                  52.509285
# Placebo                     54.033581                  52.288934
# Propriva                    52.393463                  50.909965
# Ramicane                    40.216745                  40.673236
# Stelasyn                    54.233149                  52.431737
# Zoniferol                   53.236507                  51.818479
#
#               Standard Deviation  Standard Error of the Mean
# Drug Regimen
# Capomulin               4.994774                    0.329346
# Ceftamin                6.268188                    0.469821
# Infubinol               6.567243                    0.492236
# Ketapril                8.279709                    0.603860
# Naftisol                8.134708                    0.596466
# Placebo                 7.821003                    0.581331
# Propriva                6.568014                    0.525862
# Ramicane                4.846308                    0.320955
# Stelasyn                7.710419                    0.573111
# Zoniferol               6.966589                    0.516398

# %%
#Using DataFrame.plot() to create a bar plot of the total number of measurements taken for each drug regimen
placeholder.count().plot.bar(y = 'Timepoint',title = 'Total Experiments Taken For Each Drug Regimen',ylabel='Count')
plt.legend(['Total Experiments'])
plt.show()

# %%
#Using Matplotlib's pyplot to create a bar plot of the total number of measurements taken for each drug regimen
fig = plt.figure()
t = placeholder['Timepoint'].count()
x = np.arange(len(t))
labels = ['Capomulin','Ceftamin', 'Infubinol', 'Ketapril','Naftisol','Placebo', 
       'Propriva','Ramicane', 'Stelasyn', 'Zoniferol']
plt.bar(x,t,width = 0.5)
plt.xticks(x,labels,rotation=90)
plt.title('Total Experiments Taken For Each Drug Regimen')
plt.xlabel('Drug Regimen')
plt.ylabel('Count')
plt.legend(labels=['Total Experiments'])
plt.show()

# %%
#Using DataFrame.plot() to shoe the distribution of gender of mice in the study
placeholder3 = cleaned_df.groupby('Sex')['Timepoint'].count()
placeholder3.plot.pie(ylabel = ' ', title = 'Distibution of Particpants by Gender', autopct='%1.1f%%')
plt.show()

# %%
#Using Matplotlib's pyplot to shoe the distribution of gender of mice in the study
fig = plt.figure()
x = np.array(placeholder3)
labels = ['Female','Male']
plt.pie(x,labels=labels, autopct = '%1.1f%%')
plt.title('Distibution of Particpants by Gender')
plt.show()

# %%
#Finding final tumor volume per mouse 
sorted_df = cleaned_df.loc[cleaned_df['Drug Regimen'].isin(['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin'])]
sorted_df = sorted_df.sort_values(by = ['Drug Regimen', 'Mouse ID', 'Timepoint']).reset_index()

drug_regimen = []
mouse_id = []
final_vol = []

for i in range(1,len(sorted_df.index)):
    if sorted_df.at[i,'Mouse ID'] != sorted_df.at[i-1,'Mouse ID']:
        mouse_id.append(sorted_df.at[i-1,'Mouse ID'])
        drug_regimen.append(sorted_df.at[i-1,'Drug Regimen'])
        final_vol.append(sorted_df.at[i-1,'Tumor Volume (mm3)'])
    if i == max(range(1,len(sorted_df.index))):
        mouse_id.append(sorted_df.at[i,'Mouse ID'])
        drug_regimen.append(sorted_df.at[i,'Drug Regimen'])
        final_vol.append(sorted_df.at[i,'Tumor Volume (mm3)'])
                         
                         
final_vol_data = {'Drug Regimen': drug_regimen,
                'Mouse ID': mouse_id,
                'Final Tumor Volume (mm3)': final_vol}
                         
final_vol_df = pd.DataFrame(final_vol_data)
final_vol_df = final_vol_df.groupby('Drug Regimen')

# %%
Capomulin = final_vol_df.get_group('Capomulin').reset_index()
Ramicane = final_vol_df.get_group('Ramicane').reset_index()
Infubinol = final_vol_df.get_group('Infubinol').reset_index()
Ceftamin = final_vol_df.get_group('Ceftamin').reset_index()
drug_dict = {'Capomulin': Capomulin, 'Ramicane': Ramicane, 'Infubinol': Infubinol, 'Ceftamin' : Ceftamin}


#Calculating quartiles and IQR and finding if there are any outliers

for key in drug_dict:
    quartile = drug_dict[key].quantile([0.25,0.5,0.75])
    lowerq = quartile.at[0.25,'Final Tumor Volume (mm3)']
    upperq = quartile.at[0.75,'Final Tumor Volume (mm3)']
    iqr = upperq-lowerq
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    for i in range(len(drug_dict[key].index)):
        vol = drug_dict[key].at[i,'Final Tumor Volume (mm3)']
        mouse_id = drug_dict[key].at[i,'Mouse ID']
        if vol < lower_bound:
            print(f'Mouse {mouse_id} has an a tumor volume ({vol} mm3) below the lower bound {lower_bound} for drug {key}')
        elif vol > upper_bound:
            print(f'Mouse {mouse_id} has an a tumor volume ({vol} mm3) above the upper bound {lower_bound} for drug {key}')
# Out:
# Mouse c326 has an a tumor volume (36.321345799999996 mm3) below the lower bound 36.83290494999999 for drug Infubinol

# %%
#Using Matplotlib to create box and whisker plots of final tumor vo
Capomulin_1 = Capomulin['Final Tumor Volume (mm3)']
Ramicane_1 = Ramicane['Final Tumor Volume (mm3)']
Infubinol_1 = Infubinol['Final Tumor Volume (mm3)']
Ceftamin_1 = Ceftamin['Final Tumor Volume (mm3)']


fig = plt.figure
drug = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']
drug_list = [Capomulin_1, Ramicane_1, Infubinol_1, Ceftamin_1]
maj_diamond = dict(markerfacecolor ='m',marker='D')
plt.boxplot(drug_list, labels = drug,flierprops=maj_diamond)
plt.title('Final Tumor Volume per Mouse For Each Drug Regimen')
plt.ylabel('Final Tumor Volume (mm3)')
plt.xlabel('Drug Regimen')
plt.show()

# %%
#A line plot of a mouse's tumor volume that was treated with Capomulin 
z = cleaned_df.groupby('Mouse ID')
y = z.get_group('b128')
y.plot.line(x='Timepoint',y='Tumor Volume (mm3)',title = 'Mouse ID: b128 Tumor Volume Over Time', ylabel = 'Tumor Volume (mm3)')
plt.show()

# %%
#Scatter plot of mouse weight versus average tumor volume
t = sorted_df.groupby('Drug Regimen')
p = t.get_group('Capomulin').groupby('Mouse ID').mean()
x_values = p['Weight (g)']
y_values = p['Tumor Volume (mm3)']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = 'y = ' + str(round(slope,2)) + 'x +' + str(round(intercept,2))

fig = plt.figure()
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,'g-', label = line_eq)
plt.legend()
plt.title('Average Tumor Volume related to Mouse Weight for Capomulin Drug Regimen')
plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume')
plt.show()

# %%
#Calculating correlation coeffient
correlation = st.pearsonr(x_values,y_values)
print(f'The correlation coeffienct for the mouse weight and tumor volume is {correlation[0]}, suggesting they are highly correlated')
# Out:
# The correlation coeffienct for the mouse weight and tumor volume is 0.8419363424694717, suggesting they are highly correlated
